# %%
print ('Hello Capstone Project Course!')
import numpy as np
import pandas as pd
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# This is a special file that I have created to try my hand in Capstone Coursera course by IBM. Wish me luck!
